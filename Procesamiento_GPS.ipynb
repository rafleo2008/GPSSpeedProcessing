# %%
## Algoritmo para procesar GPS
## Entradas


import pandas as pd
import geopandas as gpd
import matplotlib as mpl
import matplotlib.pyplot as plt
import fiona

import numpy as np

# %%
procesarGPS("Recorrido Carolina.gpx", "Geofences.shp", "Buses calzada lenta",3)
procesarGPS("Recorrido Juan Diego.gpx", "Geofences.shp", "Livianos Calzada lenta",3)
procesarGPS("Recorrido Jeffrey.gpx", "Geofences.shp", "Livianos Calzada Rapida",3)
# Out:
# C:\Users\rafle\anaconda3\lib\site-packages\geopandas\geodataframe.py:1322: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# C:\Users\rafle\anaconda3\lib\site-packages\geopandas\geodataframe.py:1322: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# C:\Users\rafle\anaconda3\lib\site-packages\geopandas\geodataframe.py:1322: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# C:\Users\rafle\anaconda3\lib\site-packages\geopandas\geodataframe.py:1322: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# C:\Users\rafle\anaconda3\lib\site-packages\geopandas\geodataframe.py:1322: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# C:\Users\rafle\anaconda3\lib\site-packages\geopandas\geodataframe.py:1322: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# C:\Users\rafle\anaconda3\lib\site-packages\geopandas\geodataframe.py:1322: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# C:\Users\rafle\anaconda3\lib\site-packages\geopandas\geodataframe.py:1322: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# C:\Users\rafle\anaconda3\lib\site-packages\geopandas\geodataframe.py:1322: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# C:\Users\rafle\anaconda3\lib\site-packages\geopandas\geodataframe.py:1322: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# C:\Users\rafle\anaconda3\lib\site-packages\geopandas\geodataframe.py:1322: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# C:\Users\rafle\anaconda3\lib\site-packages\geopandas\geodataframe.py:1322: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# C:\Users\rafle\anaconda3\lib\site-packages\geopandas\geodataframe.py:1322: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# C:\Users\rafle\anaconda3\lib\site-packages\geopandas\geodataframe.py:1322: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# C:\Users\rafle\anaconda3\lib\site-packages\geopandas\geodataframe.py:1322: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# C:\Users\rafle\anaconda3\lib\site-packages\geopandas\geodataframe.py:1322: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# C:\Users\rafle\anaconda3\lib\site-packages\geopandas\geodataframe.py:1322: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# C:\Users\rafle\anaconda3\lib\site-packages\geopandas\geodataframe.py:1322: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# C:\Users\rafle\anaconda3\lib\site-packages\geopandas\geodataframe.py:1322: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# C:\Users\rafle\anaconda3\lib\site-packages\geopandas\geodataframe.py:1322: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
#       track_fid  track_seg_point_id                 time     ano  mes  dia  \
# 112           1                  94  2021-08-04T11:55:53  2021.0  8.0  4.0
# 113           1                  95  2021-08-04T11:56:04  2021.0  8.0  4.0
# 114           1                  96  2021-08-04T11:56:17  2021.0  8.0  4.0
# 115           1                  97  2021-08-04T11:56:31  2021.0  8.0  4.0
# 116           1                  98  2021-08-04T11:56:43  2021.0  8.0  4.0
# ...         ...                 ...                  ...     ...  ...  ...
# 1628          3                 784  2021-08-07T19:52:16  2021.0  8.0  7.0
# 1629          3                 785  2021-08-07T19:52:29  2021.0  8.0  7.0
# 1630          3                 786  2021-08-07T19:52:40  2021.0  8.0  7.0
# 1631          3                 787  2021-08-07T19:52:51  2021.0  8.0  7.0
# 1632          3                 788  2021-08-07T19:53:06  2021.0  8.0  7.0
#
#       hora  minuto  segundo  tiempo_seg  ... Velocidad_Km_h Track_no  \
# 112   11.0    55.0     53.0         NaN  ...            NaN      NaN
# 113   11.0    56.0      4.0         NaN  ...            NaN      NaN
# 114   11.0    56.0     17.0         NaN  ...            NaN      NaN
# 115   11.0    56.0     31.0         NaN  ...            NaN      NaN
# 116   11.0    56.0     43.0         NaN  ...            NaN      NaN
# ...    ...     ...      ...         ...  ...            ...      ...
# 1628  19.0    52.0     16.0         NaN  ...            NaN      NaN
# 1629  19.0    52.0     29.0         NaN  ...            NaN      NaN
# 1630  19.0    52.0     40.0         NaN  ...            NaN      NaN
# 1631  19.0    52.0     51.0         NaN  ...            NaN      NaN
# 1632  19.0    53.0      6.0         NaN  ...            NaN      NaN
#
#                      Modo tiempo_segundos  Nombre_right  Desde_right  \
# 112   Buses calzada lenta        388553.0    Segmento 5     Calle 24
# 113   Buses calzada lenta        388564.0    Segmento 5     Calle 24
# 114   Buses calzada lenta        388577.0    Segmento 5     Calle 24
# 115   Buses calzada lenta        388591.0    Segmento 5     Calle 24
# 116   Buses calzada lenta        388603.0    Segmento 5     Calle 24
# ...                   ...             ...           ...          ...
# 1628  Buses calzada lenta        676336.0    Segmento 1     Américas
# 1629  Buses calzada lenta        676349.0    Segmento 1     Américas
# 1630  Buses calzada lenta        676360.0    Segmento 1     Américas
# 1631  Buses calzada lenta        676371.0    Segmento 1     Américas
# 1632  Buses calzada lenta        676386.0           NaN          NaN
#
#       Hasta_right      Dist_m   Vel_Km_h No_Recorrido
# 112      Calle 26  316.867054  67.101259          1.0
# 113      Calle 26   64.681619  21.168530          1.0
# 114      Calle 26   44.478455  12.317111          1.0
# 115      Calle 26  112.507061  28.930387          1.0
# 116      Calle 26   89.205820  26.761746          1.0
# ...           ...         ...        ...          ...
# 1628     Calle 13   14.342847   4.694023         20.0
# 1629     Calle 13   91.412307  25.314177         20.0
# 1630     Calle 13   88.312395  28.902238         20.0
# 1631     Calle 13   43.744390  14.316346         20.0
# 1632          NaN   50.813575  12.195258         20.0
#
# [891 rows x 25 columns]
# C:\Users\rafle\anaconda3\lib\site-packages\geopandas\geodataframe.py:1322: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# C:\Users\rafle\anaconda3\lib\site-packages\geopandas\geodataframe.py:1322: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# C:\Users\rafle\anaconda3\lib\site-packages\geopandas\geodataframe.py:1322: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# C:\Users\rafle\anaconda3\lib\site-packages\geopandas\geodataframe.py:1322: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# C:\Users\rafle\anaconda3\lib\site-packages\geopandas\geodataframe.py:1322: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# C:\Users\rafle\anaconda3\lib\site-packages\geopandas\geodataframe.py:1322: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# C:\Users\rafle\anaconda3\lib\site-packages\geopandas\geodataframe.py:1322: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# C:\Users\rafle\anaconda3\lib\site-packages\geopandas\geodataframe.py:1322: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# C:\Users\rafle\anaconda3\lib\site-packages\geopandas\geodataframe.py:1322: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# C:\Users\rafle\anaconda3\lib\site-packages\geopandas\geodataframe.py:1322: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# C:\Users\rafle\anaconda3\lib\site-packages\geopandas\geodataframe.py:1322: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# C:\Users\rafle\anaconda3\lib\site-packages\geopandas\geodataframe.py:1322: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# C:\Users\rafle\anaconda3\lib\site-packages\geopandas\geodataframe.py:1322: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# C:\Users\rafle\anaconda3\lib\site-packages\geopandas\geodataframe.py:1322: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# C:\Users\rafle\anaconda3\lib\site-packages\geopandas\geodataframe.py:1322: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# C:\Users\rafle\anaconda3\lib\site-packages\geopandas\geodataframe.py:1322: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# C:\Users\rafle\anaconda3\lib\site-packages\geopandas\geodataframe.py:1322: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# C:\Users\rafle\anaconda3\lib\site-packages\geopandas\geodataframe.py:1322: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# C:\Users\rafle\anaconda3\lib\site-packages\geopandas\geodataframe.py:1322: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# C:\Users\rafle\anaconda3\lib\site-packages\geopandas\geodataframe.py:1322: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# C:\Users\rafle\anaconda3\lib\site-packages\geopandas\geodataframe.py:1322: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# C:\Users\rafle\anaconda3\lib\site-packages\geopandas\geodataframe.py:1322: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# C:\Users\rafle\anaconda3\lib\site-packages\geopandas\geodataframe.py:1322: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# C:\Users\rafle\anaconda3\lib\site-packages\geopandas\geodataframe.py:1322: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# C:\Users\rafle\anaconda3\lib\site-packages\geopandas\geodataframe.py:1322: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# C:\Users\rafle\anaconda3\lib\site-packages\geopandas\geodataframe.py:1322: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# C:\Users\rafle\anaconda3\lib\site-packages\geopandas\geodataframe.py:1322: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# C:\Users\rafle\anaconda3\lib\site-packages\geopandas\geodataframe.py:1322: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# C:\Users\rafle\anaconda3\lib\site-packages\geopandas\geodataframe.py:1322: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# C:\Users\rafle\anaconda3\lib\site-packages\geopandas\geodataframe.py:1322: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
#       track_fid  track_seg_point_id                 time     ano  mes  dia  \
# 66            1                  52  2021-08-04T11:13:09  2021.0  8.0  4.0
# 67            1                  53  2021-08-04T11:13:19  2021.0  8.0  4.0
# 68            1                  54  2021-08-04T11:13:29  2021.0  8.0  4.0
# 70            1                  56  2021-08-04T11:13:58  2021.0  8.0  4.0
# 71            1                  57  2021-08-04T11:14:09  2021.0  8.0  4.0
# ...         ...                 ...                  ...     ...  ...  ...
# 2583          3                 985  2021-08-07T19:37:18  2021.0  8.0  7.0
# 2584          3                 986  2021-08-07T19:37:33  2021.0  8.0  7.0
# 2585          3                 987  2021-08-07T19:37:44  2021.0  8.0  7.0
# 2586          3                 988  2021-08-07T19:37:56  2021.0  8.0  7.0
# 2587          3                 989  2021-08-07T19:38:07  2021.0  8.0  7.0
#
#       hora  minuto  segundo  tiempo_seg  ... Velocidad_Km_h Track_no  \
# 66    11.0    13.0      9.0         NaN  ...            NaN      NaN
# 67    11.0    13.0     19.0         NaN  ...            NaN      NaN
# 68    11.0    13.0     29.0         NaN  ...            NaN      NaN
# 70    11.0    13.0     58.0         NaN  ...            NaN      NaN
# 71    11.0    14.0      9.0         NaN  ...            NaN      NaN
# ...    ...     ...      ...         ...  ...            ...      ...
# 2583  19.0    37.0     18.0         NaN  ...            NaN      NaN
# 2584  19.0    37.0     33.0         NaN  ...            NaN      NaN
# 2585  19.0    37.0     44.0         NaN  ...            NaN      NaN
# 2586  19.0    37.0     56.0         NaN  ...            NaN      NaN
# 2587  19.0    38.0      7.0         NaN  ...            NaN      NaN
#
#                         Modo tiempo_segundos  Nombre_right  Desde_right  \
# 66    Livianos Calzada lenta        385989.0    Segmento 1     Américas
# 67    Livianos Calzada lenta        385999.0    Segmento 1     Américas
# 68    Livianos Calzada lenta        386009.0    Segmento 1     Américas
# 70    Livianos Calzada lenta        386038.0    Segmento 1     Américas
# 71    Livianos Calzada lenta        386049.0    Segmento 1     Américas
# ...                      ...             ...           ...          ...
# 2583  Livianos Calzada lenta        675438.0    Segmento 5     Calle 24
# 2584  Livianos Calzada lenta        675453.0    Segmento 5     Calle 24
# 2585  Livianos Calzada lenta        675464.0    Segmento 5     Calle 24
# 2586  Livianos Calzada lenta        675476.0    Segmento 5     Calle 24
# 2587  Livianos Calzada lenta        675487.0           NaN          NaN
#
#       Hasta_right      Dist_m   Vel_Km_h No_Recorrido
# 66       Calle 13   40.227348  10.344175          1.0
# 67       Calle 13   23.242566   8.367324          1.0
# 68       Calle 13    9.746986   3.508915          1.0
# 70       Calle 13   49.884217  14.965265          1.0
# 71       Calle 13   57.823741  18.924133          1.0
# ...           ...         ...        ...          ...
# 2583     Calle 26   64.936482  25.974593         30.0
# 2584     Calle 26  147.809780  35.474347         30.0
# 2585     Calle 26  135.686622  44.406531         30.0
# 2586     Calle 26  128.775938  38.632781         30.0
# 2587          NaN   91.903048  30.077361         30.0
#
# [1441 rows x 25 columns]
# C:\Users\rafle\anaconda3\lib\site-packages\geopandas\geodataframe.py:1322: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# C:\Users\rafle\anaconda3\lib\site-packages\geopandas\geodataframe.py:1322: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# C:\Users\rafle\anaconda3\lib\site-packages\geopandas\geodataframe.py:1322: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# C:\Users\rafle\anaconda3\lib\site-packages\geopandas\geodataframe.py:1322: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# C:\Users\rafle\anaconda3\lib\site-packages\geopandas\geodataframe.py:1322: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# C:\Users\rafle\anaconda3\lib\site-packages\geopandas\geodataframe.py:1322: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# C:\Users\rafle\anaconda3\lib\site-packages\geopandas\geodataframe.py:1322: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# C:\Users\rafle\anaconda3\lib\site-packages\geopandas\geodataframe.py:1322: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# C:\Users\rafle\anaconda3\lib\site-packages\geopandas\geodataframe.py:1322: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# C:\Users\rafle\anaconda3\lib\site-packages\geopandas\geodataframe.py:1322: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# C:\Users\rafle\anaconda3\lib\site-packages\geopandas\geodataframe.py:1322: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# C:\Users\rafle\anaconda3\lib\site-packages\geopandas\geodataframe.py:1322: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# C:\Users\rafle\anaconda3\lib\site-packages\geopandas\geodataframe.py:1322: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# C:\Users\rafle\anaconda3\lib\site-packages\geopandas\geodataframe.py:1322: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# C:\Users\rafle\anaconda3\lib\site-packages\geopandas\geodataframe.py:1322: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# C:\Users\rafle\anaconda3\lib\site-packages\geopandas\geodataframe.py:1322: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# C:\Users\rafle\anaconda3\lib\site-packages\geopandas\geodataframe.py:1322: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# C:\Users\rafle\anaconda3\lib\site-packages\geopandas\geodataframe.py:1322: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# C:\Users\rafle\anaconda3\lib\site-packages\geopandas\geodataframe.py:1322: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# C:\Users\rafle\anaconda3\lib\site-packages\geopandas\geodataframe.py:1322: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# C:\Users\rafle\anaconda3\lib\site-packages\geopandas\geodataframe.py:1322: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# C:\Users\rafle\anaconda3\lib\site-packages\geopandas\geodataframe.py:1322: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# C:\Users\rafle\anaconda3\lib\site-packages\geopandas\geodataframe.py:1322: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# C:\Users\rafle\anaconda3\lib\site-packages\geopandas\geodataframe.py:1322: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# C:\Users\rafle\anaconda3\lib\site-packages\geopandas\geodataframe.py:1322: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# C:\Users\rafle\anaconda3\lib\site-packages\geopandas\geodataframe.py:1322: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# C:\Users\rafle\anaconda3\lib\site-packages\geopandas\geodataframe.py:1322: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# C:\Users\rafle\anaconda3\lib\site-packages\geopandas\geodataframe.py:1322: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# C:\Users\rafle\anaconda3\lib\site-packages\geopandas\geodataframe.py:1322: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# C:\Users\rafle\anaconda3\lib\site-packages\geopandas\geodataframe.py:1322: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# C:\Users\rafle\anaconda3\lib\site-packages\geopandas\geodataframe.py:1322: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
#       track_fid  track_seg_point_id                 time     ano  mes  dia  \
# 48            1                  37  2021-08-04T10:56:38  2021.0  8.0  4.0
# 49            1                  38  2021-08-04T10:56:48  2021.0  8.0  4.0
# 50            1                  39  2021-08-04T10:57:03  2021.0  8.0  4.0
# 51            1                  40  2021-08-04T10:57:17  2021.0  8.0  4.0
# 52            1                  41  2021-08-04T10:57:28  2021.0  8.0  4.0
# ...         ...                 ...                  ...     ...  ...  ...
# 2201          4                 894  2021-08-07T19:34:27  2021.0  8.0  7.0
# 2202          4                 895  2021-08-07T19:34:34  2021.0  8.0  7.0
# 2203          4                 896  2021-08-07T19:34:42  2021.0  8.0  7.0
# 2204          4                 897  2021-08-07T19:34:56  2021.0  8.0  7.0
# 2205          4                 898  2021-08-07T19:35:11  2021.0  8.0  7.0
#
#       hora  minuto  segundo  tiempo_seg  ... Velocidad_Km_h Track_no  \
# 48    10.0    56.0     38.0         NaN  ...            NaN      NaN
# 49    10.0    56.0     48.0         NaN  ...            NaN      NaN
# 50    10.0    57.0      3.0         NaN  ...            NaN      NaN
# 51    10.0    57.0     17.0         NaN  ...            NaN      NaN
# 52    10.0    57.0     28.0         NaN  ...            NaN      NaN
# ...    ...     ...      ...         ...  ...            ...      ...
# 2201  19.0    34.0     27.0         NaN  ...            NaN      NaN
# 2202  19.0    34.0     34.0         NaN  ...            NaN      NaN
# 2203  19.0    34.0     42.0         NaN  ...            NaN      NaN
# 2204  19.0    34.0     56.0         NaN  ...            NaN      NaN
# 2205  19.0    35.0     11.0         NaN  ...            NaN      NaN
#
#                          Modo tiempo_segundos  Nombre_right  Desde_right  \
# 48    Livianos Calzada Rapida        384998.0    Segmento 1     Américas
# 49    Livianos Calzada Rapida        385008.0    Segmento 1     Américas
# 50    Livianos Calzada Rapida        385023.0    Segmento 1     Américas
# 51    Livianos Calzada Rapida        385037.0    Segmento 1     Américas
# 52    Livianos Calzada Rapida        385048.0    Segmento 1     Américas
# ...                       ...             ...           ...          ...
# 2201  Livianos Calzada Rapida        675267.0    Segmento 1     Américas
# 2202  Livianos Calzada Rapida        675274.0    Segmento 1     Américas
# 2203  Livianos Calzada Rapida        675282.0    Segmento 1     Américas
# 2204  Livianos Calzada Rapida        675296.0    Segmento 1     Américas
# 2205  Livianos Calzada Rapida        675311.0           NaN          NaN
#
#       Hasta_right      Dist_m   Vel_Km_h No_Recorrido
# 48       Calle 13   36.645411  11.993043          1.0
# 49       Calle 13  104.865236  37.751485          1.0
# 50       Calle 13  175.421238  42.101097          1.0
# 51       Calle 13  181.576178  46.691017          1.0
# 52       Calle 13  125.589897  41.102148          1.0
# ...           ...         ...        ...          ...
# 2201     Calle 13  119.085880  32.977628         32.0
# 2202     Calle 13   29.598807  15.222243         32.0
# 2203     Calle 13   91.538202  41.192191         32.0
# 2204     Calle 13  184.505735  47.444332         32.0
# 2205          NaN  208.716236  50.091897         32.0
#
# [1316 rows x 25 columns]
# C:\Users\rafle\anaconda3\lib\site-packages\geopandas\geodataframe.py:1322: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)

# %%
def procesarGPS(gpsFilename, geoZonesFilename, modo, velMin):
    
    ## Abrir GPS y zonas
    
    gpsPoints = gpd.read_file(gpsFilename, layer = 'track_points')
    geoZones = gpd.read_file("Geofences.shp")
    
    ## Proyectar puntos de GPS en planas (aptas para Colombia en general)
    
    crs = "EPSG:3116"
    gpsPoints = gpsPoints.to_crs(crs)
    
    ## Columnas relevantes

    gpsPoints = gpsPoints[['track_fid','track_seg_point_id','ele','time','geometry']]
    
    #### Etapa A: Identificar bordes y direccion de los recorridos
    
    ## Filtrar polígonos de borde 
    
    borders = geoZones[geoZones['Tipo']== 'Borde']
    
    ## 2. Spatial Join de bordes con puntos GPS

    gpsPoints = gpd.sjoin(gpsPoints, borders, how = "left", op='intersects')
    gpsPoints = gpsPoints.drop(columns=['index_right'])
    
    ## 3. Listado de tracks del GPS

    tracks = gpsPoints.track_fid.unique()
    
    ## 4. Base de datos colectora de bordes
    
    collectorDB = pd.DataFrame({'track_fid': pd.Series([],dtype = 'int'),
                           'rec_orige': pd.Series([],dtype = 'int'),
                           'Sentido': pd.Series([],dtype = 'str'),
                           'rec_destino': pd.Series([],dtype = 'int')})
    
    ## 5. Iterar cada track
    
    for track in tracks:
        
        ## Filtrar puntos del track seleccionado
        
        track_segment = gpsPoints[gpsPoints['track_fid']== track]
        tracktext = 'base'+track.astype(str)
    
        ### Eliminar puntos intermedios, (fuera de los polígonos de los bordes)
    
        trackBorderPoints = track_segment[track_segment[['Nombre']].notnull().all(1)]
    
        ### Cuando el nombre no sea igual entre celdas, se marca como cambio de dirección
    
        trackBorderPoints['track_seg_point_id_destino'] = trackBorderPoints.track_seg_point_id.shift(-1)
        trackBorderPoints['Nombre_destino'] = trackBorderPoints.Nombre.shift(-1)
        
        trackBorderPoints = trackBorderPoints[trackBorderPoints['Nombre'] != trackBorderPoints['Nombre_destino']]
        trackBorderPoints['Sentido'] = 'De '+ trackBorderPoints['Nombre'] + ' a ' +  trackBorderPoints['Nombre_destino']
        trackBorderPoints = trackBorderPoints[trackBorderPoints['Nombre_destino'].notnull()]
    
        #Exportar archivo de puntos de cambio de sentido    
        #trackBorderPoints.to_csv(tracktext + '.csv')
        
        ## Juntar el procesamiento de cambio de sentido de todos los tracks
        
        collectorDB = collectorDB.append(trackBorderPoints[['track_fid','track_seg_point_id','Sentido','track_seg_point_id_destino']])
        #print(trackBorderPoints[['track_fid','track_seg_point_id','Sentido','track_seg_point_id_destino']])
    
    ### Etapa B: Filtrar basado en los puntos de cambio de sentido
    
    ## Filtrar zonas que representan los segmentos
    
    segmentos = geoZones[geoZones ['Tipo']=='Segmento']
    segmentos
    
    minSpeed = velMin
    #minSpeed = 3
    #modo = "Auto"

    ## Procesar timestamp, convertir a un valor en segundos basados en el mes

    gpsPoints['time']=gpsPoints['time'].astype('string')
    gpsPoints['ano']= gpsPoints['time'].str.slice(0,4,1).astype(float)
    gpsPoints['mes']= gpsPoints['time'].str.slice(5,7,1).astype(float)
    gpsPoints['dia']= gpsPoints['time'].str.slice(8,10,1).astype(float)
    gpsPoints['hora']= gpsPoints['time'].str.slice(11,13,1).astype(float)
    gpsPoints['minuto']= gpsPoints['time'].str.slice(14,16,1).astype(float)
    gpsPoints['segundo']= gpsPoints['time'].str.slice(17,19,1).astype(float)
    
    ## Calcular en segundos, código puede fallar si se toman datos entre cambio de mes a medianoche

    gpsPoints['tiempo_segundos'] = gpsPoints['dia']*(24*3600)+gpsPoints['hora']*3600+gpsPoints['minuto']*60+gpsPoints['segundo']

    ## Crear base para compilar los recorridos

    CompilaRecorridos = pd.DataFrame({'track_fid': pd.Series([], dtype = 'int'),
                                  'track_seg_point_id': pd.Series([], dtype = 'int'),
                                  'time': pd.Series([], dtype = 'str'),
                                  'ano': pd.Series([], dtype = 'int'),
                                  'mes': pd.Series([], dtype = 'int'),
                                  'dia': pd.Series([], dtype = 'int'),
                                  'hora': pd.Series([], dtype = 'int'),
                                  'minuto': pd.Series([], dtype = 'int'),
                                  'segundo': pd.Series([], dtype = 'int'),
                                  'tiempo_seg': pd.Series([], dtype = 'int'),
                                  'Sentido': pd.Series([], dtype = 'str'),
                                  'Segmento': pd.Series([], dtype = 'str'),
                                  'Desde': pd.Series([], dtype = 'str'),
                                  'Hasta': pd.Series([], dtype = 'str'),
                                  'Distancia_metros': pd.Series([], dtype = 'float'),
                                  'Velocidad_Km_h': pd.Series([], dtype = 'float'),
                                  'Track_no':pd.Series([], dtype = 'int'),
                                  'Modo':pd.Series([], dtype = 'str'),
    })


    ## Procesar para cada track los recorridos
    viaje = 1
    for row in collectorDB.iterrows():
    
        Track = row[1][0]
        Sentido = row[1][2]
        reg_inicio =row[1][4]
        reg_fin = row[1][5]
        #print(row)
        #print(Track)
        #print(Sentido)
        #print(reg_inicio)
        #print(reg_fin)
    
        trip = gpsPoints[(gpsPoints['track_seg_point_id']>=reg_inicio) & (gpsPoints['track_seg_point_id']<=reg_fin) &(gpsPoints['track_fid']== Track)]
        trip['Sentido'] = Sentido
    
        tripTagged = gpd.sjoin(trip, segmentos, how = 'left', op ='intersects' )
      
        # Cálculo de tiempo en cada timestep (el tiempo del timestep i es calculado con el registro anterior)
        tripTagged['Xi'] = tripTagged.geometry.x
        tripTagged['Yi'] = tripTagged.geometry.y
        tripTagged['Xi_1'] = tripTagged.Xi.shift()
        tripTagged['Yi_1'] = tripTagged.Yi.shift()
    
        tripTagged['Time_s'] = tripTagged['tiempo_segundos']-tripTagged.tiempo_segundos.shift()
        tripTagged['Dist_m'] = np.sqrt(pow((tripTagged['Xi']-tripTagged['Xi_1']),2)+pow((tripTagged['Yi']-tripTagged['Yi_1']),2))
        tripTagged['Vel_Km_h'] = (tripTagged['Dist_m']/tripTagged['Time_s'])*3.6
        ## Filter based on a min speed valule
        tripTagged['No_Recorrido'] = viaje
        tripTagged['Modo'] = modo
        tripTagged = tripTagged[tripTagged['Vel_Km_h'] >= minSpeed]
        fileName = 'Viaje_'+str(viaje)+'.csv'
        tripTagged.to_csv(fileName)
    
        tripShort = tripTagged[['track_fid','track_seg_point_id','time','ano','mes','dia','hora','minuto','segundo','tiempo_segundos','Sentido','Nombre_right','Desde_right','Hasta_right','Dist_m','Vel_Km_h','No_Recorrido','Modo']]
    
        CompilaRecorridos = CompilaRecorridos.append(tripShort)
        #print(trip)
        viaje = viaje+1
        #print(row['track_seg_point_id'])

    print(CompilaRecorridos)
    CompilaRecorridos.to_csv("Resultados_"+gpsFilename+".csv")

# %%
## Borrador de desarrollo

# %%
## Abrir archivos V2.0

gpsPoints = gpd.read_file("Recorrido Carolina.gpx", layer = 'track_points')
geoZones = gpd.read_file("Geofences.shp")


## Reproyectar a coordenadas planas locales

crs = "EPSG:3116"
gpsPoints = gpsPoints.to_crs(crs)

## Select Key columns

gpsPoints = gpsPoints[['track_fid','track_seg_point_id','ele','time','geometry']]

####### GPS Direction 

## Border Spatial Join
### 1. Filter border polygon

borders = geoZones[geoZones['Tipo']== 'Borde']

### 2. Spatial Join of borders

gpsPoints = gpd.sjoin(gpsPoints, borders, how = "left", op='intersects')
gpsPoints = gpsPoints.drop(columns=['index_right'])
### 3. Get tracks

tracks = gpsPoints.track_fid.unique()

### Loop each track

collectorDB = pd.DataFrame({'track_fid': pd.Series([],dtype = 'int'),
                           'rec_orige': pd.Series([],dtype = 'int'),
                           'Sentido': pd.Series([],dtype = 'str'),
                           'rec_destino': pd.Series([],dtype = 'int')})
                           
    
    
for track in tracks:
    track_segment = gpsPoints[gpsPoints['track_fid']== track]
    tracktext = 'base'+track.astype(str)
    
    ### Filter border points
    
    trackBorderPoints = track_segment[track_segment[['Nombre']].notnull().all(1)]
    
    ### Identify changes in direction (when row= Norte, and row+1 = Sur)
    
       
    trackBorderPoints['track_seg_point_id_destino'] = trackBorderPoints.track_seg_point_id.shift(-1)
    trackBorderPoints['Nombre_destino'] = trackBorderPoints.Nombre.shift(-1)

    trackBorderPoints = trackBorderPoints[trackBorderPoints['Nombre'] != trackBorderPoints['Nombre_destino']]
    trackBorderPoints['Sentido'] = 'De '+ trackBorderPoints['Nombre'] + ' a ' +  trackBorderPoints['Nombre_destino']
    trackBorderPoints = trackBorderPoints[trackBorderPoints['Nombre_destino'].notnull()]
    
    #print(trackBorderPoints)    
    trackBorderPoints.to_csv(tracktext + '.csv')
    
    collectorDB = collectorDB.append(trackBorderPoints[['track_fid','track_seg_point_id','Sentido','track_seg_point_id_destino']])
    print(trackBorderPoints[['track_fid','track_seg_point_id','Sentido','track_seg_point_id_destino']])
# Out:
# Empty DataFrame
# Columns: [track_fid, track_seg_point_id, Sentido, track_seg_point_id_destino]
# Index: []
#      track_fid  track_seg_point_id         Sentido  track_seg_point_id_destino
# 111          1                  93  De Norte a Sur                       144.0
# 178          1                 160  De Sur a Norte                       228.0
# 263          1                 245  De Norte a Sur                       282.0
# 316          1                 298  De Sur a Norte                       377.0
# 415          1                 397  De Norte a Sur                       430.0
#      track_fid  track_seg_point_id         Sentido  track_seg_point_id_destino
# 496          2                  32  De Sur a Norte                        74.0
# 548          2                  84  De Norte a Sur                       188.0
# 748          2                 284  De Sur a Norte                       318.0
#       track_fid  track_seg_point_id         Sentido  \
# 855           3                  11  De Sur a Norte
# 911           3                  67  De Norte a Sur
# 974           3                 130  De Sur a Norte
# 1034          3                 190  De Norte a Sur
# 1087          3                 243  De Sur a Norte
# 1152          3                 308  De Norte a Sur
# 1228          3                 384  De Sur a Norte
# 1298          3                 454  De Norte a Sur
# 1370          3                 526  De Sur a Norte
# 1433          3                 589  De Norte a Sur
# 1507          3                 663  De Sur a Norte
# 1578          3                 734  De Norte a Sur
#
#       track_seg_point_id_destino
# 855                         47.0
# 911                        110.0
# 974                        172.0
# 1034                       227.0
# 1087                       292.0
# 1152                       360.0
# 1228                       434.0
# 1298                       509.0
# 1370                       570.0
# 1433                       637.0
# 1507                       716.0
# 1578                       788.0
# Empty DataFrame
# Columns: [track_fid, track_seg_point_id, Sentido, track_seg_point_id_destino]
# Index: []
# C:\Users\rafle\anaconda3\lib\site-packages\geopandas\geodataframe.py:1322: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# C:\Users\rafle\anaconda3\lib\site-packages\geopandas\geodataframe.py:1322: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# C:\Users\rafle\anaconda3\lib\site-packages\geopandas\geodataframe.py:1322: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)

# %%
#track_segment = gpsPoints[gpsPoints['track_fid']== 0]
#track_segment

#collectorDB
collectorDB
# Out:
#       track_fid  rec_orige         Sentido  rec_destino  track_seg_point_id  \
# 111           1        NaN  De Norte a Sur          NaN                93.0
# 178           1        NaN  De Sur a Norte          NaN               160.0
# 263           1        NaN  De Norte a Sur          NaN               245.0
# 316           1        NaN  De Sur a Norte          NaN               298.0
# 415           1        NaN  De Norte a Sur          NaN               397.0
# 496           2        NaN  De Sur a Norte          NaN                32.0
# 548           2        NaN  De Norte a Sur          NaN                84.0
# 748           2        NaN  De Sur a Norte          NaN               284.0
# 855           3        NaN  De Sur a Norte          NaN                11.0
# 911           3        NaN  De Norte a Sur          NaN                67.0
# 974           3        NaN  De Sur a Norte          NaN               130.0
# 1034          3        NaN  De Norte a Sur          NaN               190.0
# 1087          3        NaN  De Sur a Norte          NaN               243.0
# 1152          3        NaN  De Norte a Sur          NaN               308.0
# 1228          3        NaN  De Sur a Norte          NaN               384.0
# 1298          3        NaN  De Norte a Sur          NaN               454.0
# 1370          3        NaN  De Sur a Norte          NaN               526.0
# 1433          3        NaN  De Norte a Sur          NaN               589.0
# 1507          3        NaN  De Sur a Norte          NaN               663.0
# 1578          3        NaN  De Norte a Sur          NaN               734.0
#
#       track_seg_point_id_destino
# 111                        144.0
# 178                        228.0
# 263                        282.0
# 316                        377.0
# 415                        430.0
# 496                         74.0
# 548                        188.0
# 748                        318.0
# 855                         47.0
# 911                        110.0
# 974                        172.0
# 1034                       227.0
# 1087                       292.0
# 1152                       360.0
# 1228                       434.0
# 1298                       509.0
# 1370                       570.0
# 1433                       637.0
# 1507                       716.0
# 1578                       788.0

# %%
### Tag segments based on directions in collectorDB

segmentos = geoZones[geoZones ['Tipo']=='Segmento']
segmentos

minSpeed = 3
modo = "Auto"

## Procesar timestamp, convertir a un valor en segundos basados en el mes

gpsPoints['time']=gpsPoints['time'].astype('string')
gpsPoints['ano']= gpsPoints['time'].str.slice(0,4,1).astype(float)
gpsPoints['mes']= gpsPoints['time'].str.slice(5,7,1).astype(float)
gpsPoints['dia']= gpsPoints['time'].str.slice(8,10,1).astype(float)
gpsPoints['hora']= gpsPoints['time'].str.slice(11,13,1).astype(float)
gpsPoints['minuto']= gpsPoints['time'].str.slice(14,16,1).astype(float)
gpsPoints['segundo']= gpsPoints['time'].str.slice(17,19,1).astype(float)

## Calcular en segundos, código puede fallar si se toman datos entre cambio de mes a medianoche

gpsPoints['tiempo_segundos'] = gpsPoints['dia']*(24*3600)+gpsPoints['hora']*3600+gpsPoints['minuto']*60+gpsPoints['segundo']

## Crear base para compilar los recorridos

CompilaRecorridos = pd.DataFrame({'track_fid': pd.Series([], dtype = 'int'),
                                  'track_seg_point_id': pd.Series([], dtype = 'int'),
                                  'time': pd.Series([], dtype = 'str'),
                                  'ano': pd.Series([], dtype = 'int'),
                                  'mes': pd.Series([], dtype = 'int'),
                                  'dia': pd.Series([], dtype = 'int'),
                                  'hora': pd.Series([], dtype = 'int'),
                                  'minuto': pd.Series([], dtype = 'int'),
                                  'segundo': pd.Series([], dtype = 'int'),
                                  'tiempo_seg': pd.Series([], dtype = 'int'),
                                  'Sentido': pd.Series([], dtype = 'str'),
                                  'Segmento': pd.Series([], dtype = 'str'),
                                  'Desde': pd.Series([], dtype = 'str'),
                                  'Hasta': pd.Series([], dtype = 'str'),
                                  'Distancia_metros': pd.Series([], dtype = 'float'),
                                  'Velocidad_Km_h': pd.Series([], dtype = 'float'),
                                  'Track_no':pd.Series([], dtype = 'int'),
                                  'Modo':pd.Series([], dtype = 'str'),
})


## Se itera sobre cada uno de los tracks
viaje = 1
for row in collectorDB.iterrows():
    
    Track = row[1][0]
    Sentido = row[1][2]
    reg_inicio =row[1][4]
    reg_fin = row[1][5]
    #print(row)
    #print(Track)
    #print(Sentido)
    #print(reg_inicio)
    #print(reg_fin)
    
    trip = gpsPoints[(gpsPoints['track_seg_point_id']>=reg_inicio) & (gpsPoints['track_seg_point_id']<=reg_fin) &(gpsPoints['track_fid']== Track)]
    trip['Sentido'] = Sentido
    
    tripTagged = gpd.sjoin(trip, segmentos, how = 'left', op ='intersects' )
      
    # Cálculo de tiempo en cada timestep (el tiempo del timestep i es calculado con el registro anterior)
    tripTagged['Xi'] = tripTagged.geometry.x
    tripTagged['Yi'] = tripTagged.geometry.y
    tripTagged['Xi_1'] = tripTagged.Xi.shift()
    tripTagged['Yi_1'] = tripTagged.Yi.shift()
    
    tripTagged['Time_s'] = tripTagged['tiempo_segundos']-tripTagged.tiempo_segundos.shift()
    tripTagged['Dist_m'] = np.sqrt(pow((tripTagged['Xi']-tripTagged['Xi_1']),2)+pow((tripTagged['Yi']-tripTagged['Yi_1']),2))
    tripTagged['Vel_Km_h'] = (tripTagged['Dist_m']/tripTagged['Time_s'])*3.6
    ## Filter based on a min speed valule
    tripTagged['No_Recorrido'] = viaje
    tripTagged['Modo'] = modo
    tripTagged = tripTagged[tripTagged['Vel_Km_h'] >= minSpeed]
    fileName = 'Viaje_'+str(viaje)+'.csv'
    tripTagged.to_csv(fileName)
    #tripShort = 
    tripShort = tripTagged[['track_fid','track_seg_point_id','time','ano','mes','dia','hora','minuto','segundo','tiempo_segundos','Sentido','Nombre_right','Desde_right','Hasta_right','Dist_m','Vel_Km_h','No_Recorrido','Modo']]
    
    CompilaRecorridos = CompilaRecorridos.append(tripShort)
    #print(trip)
    viaje = viaje+1
    #print(row['track_seg_point_id'])

print(CompilaRecorridos)
CompilaRecorridos.to_csv("Resultados.csv")
#geofences = gpd.read_file('Geofences.shp')
#geofences
#borders
# Out:
# C:\Users\rafle\anaconda3\lib\site-packages\geopandas\geodataframe.py:1322: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# C:\Users\rafle\anaconda3\lib\site-packages\geopandas\geodataframe.py:1322: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# C:\Users\rafle\anaconda3\lib\site-packages\geopandas\geodataframe.py:1322: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# C:\Users\rafle\anaconda3\lib\site-packages\geopandas\geodataframe.py:1322: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# C:\Users\rafle\anaconda3\lib\site-packages\geopandas\geodataframe.py:1322: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# C:\Users\rafle\anaconda3\lib\site-packages\geopandas\geodataframe.py:1322: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# C:\Users\rafle\anaconda3\lib\site-packages\geopandas\geodataframe.py:1322: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# C:\Users\rafle\anaconda3\lib\site-packages\geopandas\geodataframe.py:1322: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# C:\Users\rafle\anaconda3\lib\site-packages\geopandas\geodataframe.py:1322: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# C:\Users\rafle\anaconda3\lib\site-packages\geopandas\geodataframe.py:1322: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# C:\Users\rafle\anaconda3\lib\site-packages\geopandas\geodataframe.py:1322: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# C:\Users\rafle\anaconda3\lib\site-packages\geopandas\geodataframe.py:1322: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# C:\Users\rafle\anaconda3\lib\site-packages\geopandas\geodataframe.py:1322: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# C:\Users\rafle\anaconda3\lib\site-packages\geopandas\geodataframe.py:1322: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# C:\Users\rafle\anaconda3\lib\site-packages\geopandas\geodataframe.py:1322: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# C:\Users\rafle\anaconda3\lib\site-packages\geopandas\geodataframe.py:1322: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# C:\Users\rafle\anaconda3\lib\site-packages\geopandas\geodataframe.py:1322: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# C:\Users\rafle\anaconda3\lib\site-packages\geopandas\geodataframe.py:1322: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# C:\Users\rafle\anaconda3\lib\site-packages\geopandas\geodataframe.py:1322: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
# C:\Users\rafle\anaconda3\lib\site-packages\geopandas\geodataframe.py:1322: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)
#       track_fid  track_seg_point_id                 time     ano  mes  dia  \
# 112           1                  94  2021-08-04T11:55:53  2021.0  8.0  4.0
# 113           1                  95  2021-08-04T11:56:04  2021.0  8.0  4.0
# 114           1                  96  2021-08-04T11:56:17  2021.0  8.0  4.0
# 115           1                  97  2021-08-04T11:56:31  2021.0  8.0  4.0
# 116           1                  98  2021-08-04T11:56:43  2021.0  8.0  4.0
# ...         ...                 ...                  ...     ...  ...  ...
# 1628          3                 784  2021-08-07T19:52:16  2021.0  8.0  7.0
# 1629          3                 785  2021-08-07T19:52:29  2021.0  8.0  7.0
# 1630          3                 786  2021-08-07T19:52:40  2021.0  8.0  7.0
# 1631          3                 787  2021-08-07T19:52:51  2021.0  8.0  7.0
# 1632          3                 788  2021-08-07T19:53:06  2021.0  8.0  7.0
#
#       hora  minuto  segundo  tiempo_seg  ... Velocidad_Km_h Track_no  Modo  \
# 112   11.0    55.0     53.0         NaN  ...            NaN      NaN  Auto
# 113   11.0    56.0      4.0         NaN  ...            NaN      NaN  Auto
# 114   11.0    56.0     17.0         NaN  ...            NaN      NaN  Auto
# 115   11.0    56.0     31.0         NaN  ...            NaN      NaN  Auto
# 116   11.0    56.0     43.0         NaN  ...            NaN      NaN  Auto
# ...    ...     ...      ...         ...  ...            ...      ...   ...
# 1628  19.0    52.0     16.0         NaN  ...            NaN      NaN  Auto
# 1629  19.0    52.0     29.0         NaN  ...            NaN      NaN  Auto
# 1630  19.0    52.0     40.0         NaN  ...            NaN      NaN  Auto
# 1631  19.0    52.0     51.0         NaN  ...            NaN      NaN  Auto
# 1632  19.0    53.0      6.0         NaN  ...            NaN      NaN  Auto
#
#      tiempo_segundos  Nombre_right  Desde_right  Hasta_right      Dist_m  \
# 112         388553.0    Segmento 5     Calle 24     Calle 26  316.867054
# 113         388564.0    Segmento 5     Calle 24     Calle 26   64.681619
# 114         388577.0    Segmento 5     Calle 24     Calle 26   44.478455
# 115         388591.0    Segmento 5     Calle 24     Calle 26  112.507061
# 116         388603.0    Segmento 5     Calle 24     Calle 26   89.205820
# ...              ...           ...          ...          ...         ...
# 1628        676336.0    Segmento 1     Américas     Calle 13   14.342847
# 1629        676349.0    Segmento 1     Américas     Calle 13   91.412307
# 1630        676360.0    Segmento 1     Américas     Calle 13   88.312395
# 1631        676371.0    Segmento 1     Américas     Calle 13   43.744390
# 1632        676386.0           NaN          NaN          NaN   50.813575
#
#        Vel_Km_h No_Recorrido
# 112   67.101259          1.0
# 113   21.168530          1.0
# 114   12.317111          1.0
# 115   28.930387          1.0
# 116   26.761746          1.0
# ...         ...          ...
# 1628   4.694023         20.0
# 1629  25.314177         20.0
# 1630  28.902238         20.0
# 1631  14.316346         20.0
# 1632  12.195258         20.0
#
# [891 rows x 25 columns]
